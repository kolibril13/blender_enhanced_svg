# %%
from text_to_path import convert_text_to_paths_in_svg

# Example usage:
svg_content = '''
<svg xmlns="http://www.w3.org/2000/svg">
  <text x="0" y="40"
        font-family="Calibri, sans-serif"
        font-size="40"
        fill="#000000">
    hello worlaksjhfdbd
  </text>
</svg>'''

# Convert text to paths in the SVG.
svg_with_paths = convert_text_to_paths_in_svg(svg_content)
print(svg_with_paths)

# For IPython/Jupyter, you can display it with:
from IPython.display import SVG
SVG(svg_with_paths)
# Out:
# findfont: Font family ['Calibri'] not found. Falling back to DejaVu Sans.
# <svg xmlns="http://www.w3.org/2000/svg">
# ...
