# %%
from text_to_path import convert_text_to_paths_in_svg

# Example usage:
svg_content = '''
<svg xmlns="http://www.w3.org/2000/svg">
  <text x="0" y="40"
        font-family="Calibri, sans-serif"
        font-size="40"
        fill="#000000">
    hello world
  </text>
</svg>'''

# Convert text to paths in the SVG.
svg_with_paths = convert_text_to_paths_in_svg(svg_content)
print(svg_with_paths)

# For IPython/Jupyter, you can display it with:
from IPython.display import SVG
SVG(svg_with_paths)
# Out:
# findfont: Font family ['Calibri'] not found. Falling back to DejaVu Sans.
# <svg xmlns="http://www.w3.org/2000/svg">
# ...

# %%
svg_content = """
<svg width="2827" height="1552" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:space="preserve" overflow="hidden"><defs><clipPath id="clip0"><rect x="2004" y="996" width="2827" height="1552"/></clipPath></defs><g clip-path="url(#clip0)" transform="translate(-2004 -996)"><rect x="2005" y="997" width="2824" height="1549" fill="#FFFFFF"/><g><path d="M2055.5 1282.5 2055.5 2448.5M2963.6 1282.5 2963.6 2448.5M3870.63 1282.5 3870.63 2448.5M4778.5 1282.5 4778.5 2448.5" stroke="#D9D9D9" stroke-width="3.4375" stroke-linejoin="round" stroke-miterlimit="10" fill="none"/></g><g><path d="M2330.08 1662.05 2454.08 1662.05 2454.08 2448 2330.08 2448ZM3237.11 1632.05 3361.11 1632.05 3361.11 2448 3237.11 2448ZM4145.14 1603.05 4269.14 1603.05 4269.14 2448 4145.14 2448Z" fill="#4472C4"/></g><g><path d="M2565.08 1429.05 2689.09 1429.05 2689.09 2448 2565.08 2448ZM3472.11 1516.05 3596.12 1516.05 3596.12 2448 3472.11 2448ZM4380.14 1720.06 4504.15 1720.06 4504.15 2448 4380.14 2448Z" fill="#ED7D31"/></g><g><path d="M2055.5 2448.5 4778.5 2448.5" stroke="#D9D9D9" stroke-width="3.4375" stroke-linejoin="round" stroke-miterlimit="10" fill="none" fill-rule="evenodd"/></g><g><text fill="#7F7F7F" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(6.12323e-17 -1 1 6.12323e-17 2404.53 1634)">27</text></g><g><text fill="#7F7F7F" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(6.12323e-17 -1 1 6.12323e-17 3312.03 1605)">28</text></g><g><text fill="#7F7F7F" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(6.12323e-17 -1 1 6.12323e-17 4219.53 1576)">29</text></g><g><text fill="#7F7F7F" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(6.12323e-17 -1 1 6.12323e-17 2639.45 1401)">35</text></g><g><text fill="#7F7F7F" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(6.12323e-17 -1 1 6.12323e-17 3546.95 1488)">32</text></g><g><text fill="#7F7F7F" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(6.12323e-17 -1 1 6.12323e-17 4454.45 1692)">25</text></g><g><text fill="#595959" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(1 0 0 1 2497.33 2506)">1</text></g><g><text fill="#595959" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(1 0 0 1 3404.83 2506)">2</text></g><g><text fill="#595959" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="37" transform="matrix(1 0 0 1 4312.33 2506)">3</text></g><g><text fill="#595959" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="700" font-size="73" transform="matrix(1 0 0 1 3195.67 1101)">CHART TITLE</text></g><g><rect x="3254" y="1182" width="23" height="22.9996" fill="#4472C4"/></g><g><text fill="#595959" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="41" transform="matrix(1 0 0 1 3286.6 1205)">Series1</text></g><g><rect x="3443" y="1182" width="22" height="22.9996" fill="#ED7D31"/></g><g><text fill="#595959" font-family="Calibri,Calibri_MSFontService,sans-serif" font-weight="400" font-size="41" transform="matrix(1 0 0 1 3474.99 1205)">Series2</text></g><rect x="2005.5" y="997.5" width="2824" height="1549" stroke="#D9D9D9" stroke-width="3.4375" stroke-linejoin="round" stroke-miterlimit="10" fill="none"/></g></svg>
"""
# Convert text to paths in the SVG.
svg_with_paths = convert_text_to_paths_in_svg(svg_content)

#print(svg_with_paths)

# For IPython/Jupyter, you can display it with:
from IPython.display import SVG, HTML

def display_svg(svg_content, width='100px'):
    html_content = (
        "<style>"
        ".svg-container svg { max-width: 100%; height: auto; display: block; }"
        "</style>"
    )
    html_content += f"<div class='svg-container' style='width:{width};'>{svg_content}</div>"
    display(HTML(html_content))


display_svg(svg_with_paths, width="600px")
# Out:
# <style>.svg-container svg { max-width: 100%; height: auto; display: block; }</style><div class='svg-container' style='width:600px;'><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="2827" height="1552" xml:space="preserve" overflow="hidden">
#   <defs>
#     <clipPath id="clip0">
#       <rect x="2004" y="996" width="2827" height="1552"/>
#     </clipPath>
#   </defs>
#   <g clip-path="url(#clip0)" transform="translate(-2004 -996)">
#     <rect x="2005" y="997" width="2824" height="1549" fill="#FFFFFF"/>
#     <g>
#       <path d="M2055.5 1282.5 2055.5 2448.5M2963.6 1282.5 2963.6 2448.5M3870.63 1282.5 3870.63 2448.5M4778.5 1282.5 4778.5 2448.5" stroke="#D9D9D9" stroke-width="3.4375" stroke-linejoin="round" stroke-miterlimit="10" fill="none"/>
#     </g>
#     <g>
# ...
